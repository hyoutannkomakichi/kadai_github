# %%
array=["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]

# %%
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# %%
print(array[1]) # 2番目の要素だけを表示
# Out:
# 火曜日は雨です

# %%
print(dictionary{2})#三番目の要素だけを表示
# Out:
#   File "/tmp/ipykernel_4574/2290307357.py", line 1
#     print(dictionary{2})#三番目の要素だけを表示
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(array[2]) # 3番目の要素だけを表示
# Out:
# 水曜日は晴れです

# %%
print(dictionary[2]) # 3番目の要素だけを表示
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4574/1036382269.py in <cell line: 0>()
# ----> 1 print(dictionary[2]) # 3番目の要素だけを表示
#
# KeyError: 2

# %%
print(dictionary["wed"]) # 3番目の要素だけを表示
# Out:
# 晴れ
